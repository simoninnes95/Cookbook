# %%
from typing import List

# %% [markdown]
# #### 1. Contains Duplicate

# %%
class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:

        count = {}

        for i in range(0, len(nums)):
            if nums[i] in count:
                count[nums[i]] += 1
            else: 
                count[nums[i]] = 1

        for item in list(count.values()):
            if item > 1:
                return True
        
        return False

# %%
nums = [1,2,2,3]

s = Solution()
s.hasDuplicate(nums)
# Out:
# True

# %%
class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:

        seen = set()

        for num in nums:
            if num in seen:
                return True
            seen.add(num)
        
        return False

# %%
nums = [1,2,2,3]

s = Solution()
s.hasDuplicate(nums)
# Out:
# True

# %% [markdown]
# #### 2. Valid Anagram

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        
        dict = {}

        for letter in s:
            if letter in dict:
                dict[letter] += 1
            else:
                dict[letter] = 1

        for letter in t:
            if letter in dict:
                dict[letter] -= 1
            else:
                dict[letter] = 1
        
        for item in list(dict.values()):
            if item > 0:
                return False
            
        print(dict)
        return True

# %%
s = "racecar"
t = "carrace"

sol = Solution()
sol.isAnagram(s, t)
# Out:
# False

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        
        if len(s) != len(t):
            return False
        
        return sorted(s) == sorted(t)

# %%
s = "racecar"
t = "carrace"

sol = Solution()
sol.isAnagram(s, t)
# Out:
# False

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        
        if len(s) != len(t):
            return False
        
        countS, countT = {}, {}

        for i in range(len(s)):
            countS[s[i]] = 1 + countS.get(s[i], 0)
            countT[t[i]] = 1 + countT.get(t[i], 0)

        return countS == countT

# %% [markdown]
# Time complexity:
# O(n+m)
# Space complexity:
# O(1) since we have at most 26 different characters.

# %%
s = "racecar"
t = "carrce"

sol = Solution()
sol.isAnagram(s, t)
# Out:
# False

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        if len(s) != len(t):
            return False

        count = [0] * 26
        for i in range(len(s)):
            count[ord(s[i]) - ord('a')] += 1
            count[ord(t[i]) - ord('a')] -= 1

        for val in count:
            if val != 0:
                return False
        return True

# %% [markdown]
# #### 3. Two Sum

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        
        for i in range(len(nums)):
            for j in range(i+1, len(nums)):
                if nums[i] + nums[j] == target:
                    return list([i, j])

# %%
nums = [4,5,6] 
target = 10

sol = Solution()
sol.twoSum(nums, target)
# Out:
# [0, 2]

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        
        repeat = True
        index_i, index_j = 0, 1
        while repeat:
            if nums[index_j] - target == nums[index_i]:
                repeat = True
            else:


        return [index_i, index_j]

# %%
nums = [3,4,5,6]
target = 7

sol = Solution()
sol.twoSum(nums, target)

# %% [markdown]
# #### 4. Group Anagrams

# %%
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:

        anagrams = []
        seen = set()

        for index in range(len(strs)):
            inner_list = [strs[index]]
            seen.add(strs[index])
            for jindex in range(index+1, len(strs)):
                if sorted(strs[index]) == sorted(strs[jindex]):
                    inner_list.append(strs[jindex])
            if strs[index] in seen:
                anagrams.append(inner_list)

        return anagrams




# First you are going to need to loop through each of the words
# Then for each of the words you are going to need to keep track of the letters somehow (Maybe a dict)
# 
# If two words or more are going to be anagrams you must return a list of those anagrams [[item, item 1], [x,y,x]] so instantiate an empty list

# %%
sorted("act") == sorted("cat")
# Out:
# True

# %%
strs = ["act","pots","tops","cat","stop","hat"]

s  = Solution()
s.groupAnagrams(strs)
# Out:
# [['act', 'cat'],
#  ['pots', 'tops', 'stop'],
#  ['tops', 'stop'],
#  ['cat'],
#  ['stop'],
#  ['hat']]

# %%
from datetime import datetime

# Get the current date and time
current_datetime = datetime.now()

# Access individual components
year = current_datetime.year
month = current_datetime.month
day = current_datetime.day
hour = current_datetime.hour
minute = current_datetime.minute

stamp = f"{year}{month:02d}{day:02d}_{hour:02d}{minute:02d}"

# %%
print(stamp)
# Out:
# 20260108_1419
